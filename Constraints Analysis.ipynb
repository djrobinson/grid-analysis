# %%
import pandas as pd

# If you need specific options, you can add parameters like:
df = pd.read_csv('src/data/da_constraints_20250101.csv',
                 encoding='utf-8',  # specify encoding if needed
                 sep=',',           # specify delimiter
                 header=0)

# %%
# Get unique counts for Monitored Facility
monitored_counts = df['Monitored Facility'].value_counts()
print("\nMonitored Facility Counts:")
print(monitored_counts)

# Get unique counts for Contingent Facility
contingent_counts = df['Contingent Facility'].value_counts()
print("\nContingent Facility Counts:")
print(contingent_counts)

# Optional: If you want to see total number of unique values
print(f"\nTotal unique Monitored Facilities: {df['Monitored Facility'].nunique()}")
print(f"Total unique Contingent Facilities: {df['Contingent Facility'].nunique()}")
# Out:
# Monitored Facility Counts:
# Monitored Facility
# LN TEXAS_CO -               7377
# LN GRACMONT - ANADARKO      7022
# Multi-Element Constraint    6146
# LN WR_SMKHL - SUMM          3699
# XFMR POTTER_S - POTTER_S    3240
#                             ...
# LN REDHILLS - ELK-CITY         1
# LN CUSTER - REDHILLS           1
# LN SUB_M - SHRNKRD             1
# LN SMITH-1 - PHLBUR1           1
# LN 59TH - ELPA                 1
# Name: count, Length: 978, dtype: int64
#
# Contingent Facility Counts:
# Contingent Facility
# BASE                                  33087
# WFEC CSWS:WASHIT1 SW_STA:138:1:6       3737
# OKGE:BROWN2 BODLE CANEY1:138:7:34      3259
# SPS:RDRUNNER XF TRT:345 115:3:17       2720
# GRDA OKGE:CLEVLND7 SONR1:345:1:10      2643
#                                       ...
# WAUE:POPLARWP WOLFPT:115:2:6              1
# KACY KCPL:BARBER TERRACE:161:1:12         1
# WAUE:ANTELOP LELANDO:345:1:11             1
# KCPL:LEVEE NRTHEAST:161:1:11              1
# WAUE:LELANDO2 LELANDO:345 230:4:14        1
# Name: count, Length: 838, dtype: int64
#
# Total unique Monitored Facilities: 978
# Total unique Contingent Facilities: 838

# %%
import pandas as pd
import networkx as nx

def parse_facility(facility_str: str):
    """
    Parse facility string to extract nodes, voltages, and company.
    
    Example inputs:
    - "LN FLOURNOY - WOOLWORT" -> (["FLOURNOY", "WOOLWORT"], [], None)
    - "CSWS:LEASIDE SWSHREV:138:1:9" -> (["LEASIDE", "SWSHREV"], [138.0], "CSWS")
    - "OKGE:WDWRD1 XF A:138 69:1:5" -> (["WDWRD1", "XF A"], [138.0, 69.0], "OKGE")
    - "WAUE:BELFELD XF KU1A3:345 230 13.8" -> (["BELFELD", "XF KU1A3"], [345.0, 230.0, 13.8], "WAUE")
    - "SPS:HOBBS:COMBINEDCYCLE" -> (["HOBBS"], [], "SPS")
    """
    # Parse detailed format (company:node1 node2:voltage:...)
    if ':' in facility_str:
        parts = facility_str.split(':')
        company = parts[0]
        nodes = parts[1].split()
        
        # Handle multiple voltage levels, including decimals
        voltages = []
        if len(parts) > 2:
            try:
                voltages = [float(v) for v in parts[2].split()]
            except ValueError:
                # If voltage parsing fails, just continue with empty voltages
                pass
            
        return nodes, voltages, company
        
    # Parse simple format (LN/XFMR NODE1 - NODE2)
    else:
        nodes = [n.strip() for n in facility_str.split('-')]
        if nodes[0].startswith(('LN ', 'XFMR ')):
            nodes[0] = nodes[0].split(' ', 1)[1].strip()
        return nodes, [], None

def add_constraint_to_network(row: pd.Series):
    """Add a single constraint's information to the network."""
    # Parse monitored facility
    mon_nodes, mon_voltages, mon_company = self.parse_facility(row['Monitored Facility'])
    
    # Parse contingent facility if not BASE
    if row['Contingent Facility'] != 'BASE':
        cont_nodes, cont_voltages, cont_company = self.parse_facility(row['Contingent Facility'])
    else:
        cont_nodes, cont_voltages, cont_company = [], [], None
    
    # Add nodes and edges to network
    for nodes, voltages, company in [(mon_nodes, mon_voltages, mon_company)]:
        #    (cont_nodes, cont_voltages, cont_company)]:
        if not nodes:
            continue
            
        # Add nodes with attributes
        for node in nodes:
            if node not in self.G:
                self.G.add_node(node, voltages=set(), companies=set())
            
            if voltages:
                self.G.nodes[node]['voltages'].update(voltages)
            if company:
                self.G.nodes[node]['companies'].add(company)
        
        # Add edge between nodes if it's a pair
        if len(nodes) == 2:
            self.G.add_edge(nodes[0], nodes[1], 
                          voltages=set(voltages),
                          company=company)

def build_network(constraints_df: pd.DataFrame):
    """Build network from constraints dataframe."""
    for _, row in constraints_df.iterrows():
        self.add_constraint_to_network(row)

# %%
unique_edges = df['Contingent Facility'].unique()

# Create empty lists to store data
sources = []
sinks = []
voltages = []
companies = []

# Parse each unique facility
for edge in unique_edges:
    source_sink, voltage, company = parse_facility(edge)
    print(source_sink)
    if len(source_sink) == 2:
        sources.append(node[0])
        sinks.append(node[1])
        voltages.append(voltage if voltage else None)
        companies.append(company if company else None)

# Create DataFrame from the lists
facility_df = pd.DataFrame({
    'Source': sources,
    'Sink': sinks,
    'Voltage': voltages,
    'Company': companies
})

facility_df
# Out:
# ['BASE']
# ['BLACKBRY', 'JASPER7']
# ['WAHPETN', 'HANKSON']
# ['SEMINOLE']
# ['NICHSUB', 'GRAPVINE']
# ['MCC2', 'MTGY']
# ['SHAM', 'KIRBY_SU']
# ['SETAB1', 'MINGO1']
# ['CHUB_LK', 'HELENAMN']
# ['RAUN', 'FT_CAL']
# ['SIBLEY', 'OVER']
# ['STL4391', 'JOP3891']
# ['CHAR_CK', 'PATENT_G']
# ['HOYT', 'STRA']
# ['BORDER', 'TUCO']
# ['MCCLAI', 'PLVAL']
# ['MACON345', 'AXTELL1']
# ['GRACMONT', 'ANADARKO']
# ['JUD-LR1', 'CRKCREEK']
# ['VALLIANT', 'PITTSB9']
# ['CLEVLND7', 'SONR1']
# ['WASHIT1', 'SW_STA']
# ['SEMINOLE', 'PITTSB9']
# ['MINCO', 'CIMARRON']
# ['GENTRY', 'NODAWAY', 'FAIRPORT']
# ['GAVINS', 'SPIRITM']
# ['MULGRE2', 'CIRC']
# ['BORDER', 'TUCO']
# ['N345', 'NEORDG']
# ['FORMNWA', 'ELLIOTTW']
# ['SPIRITM', 'MANNING2']
# ['COLBY3', 'MINGO1']
# ['HOLWD', 'PLVAL']
# ['SEMINOLE', 'XF', '1_3']
# ['WAYSID_W', 'STEGALL']
# ['SUB3740', 'SUB3455']
# ['SCOTSBLF', 'VICTRY_H']
# ['SUB1280', 'SUB1263']
# ['SHELDON', 'FOLSOM']
# ['CEDAR_CR', 'SHWNMSN5']
# ['JERICHO_', 'KIRBY_SU']
# ['WAGENER', 'SUB3454']
# ['BROWN2', 'BODLE', 'CANEY1']
# ['HUGOPP4', 'ATOKA2']
# ['W_GARDNR', 'LACYGNE']
# ['PECULIA7', 'STILWELL']
# ['DUNLAP', 'BOXBUTE', 'CHADRON']
# ['DRAPR1', 'CIMARRON']
# ['SUB1260', 'SUB1362']
# ['RDRUNNER', 'XF', 'TRT']
# ['C_PLAIN', 'SETAB1']
# ['MAURINE', 'NUNDRWD']
# ['DUNNING', 'EASTRUTH']
# ['KEYSTONE', 'G_GENT1']
# ['FLINTCRK', 'BROOK_LN']
# ['ARCAD7', 'NOWST1']
# ['N345', 'NSES']
# ['POSTROCK', 'SPERVI1']
# ['KEYSTONE', 'SIDNEYM']
# ['W_GARDNR', 'CRAIG']
# ['SWIS', 'EMPEC']
# ['REDWLO1', 'G_GENT1']
# ['CIMARRON', 'XF', 'A31']
# ['SUB1226', 'SUB1291']
# ['HITCH', 'MOORE_CO']
# ['MARM', 'JAY_HAWK']
# ['WAVERLY7', 'LACYGNE']
# ['CNTRVILL', 'DAKOTA']
# ['CARTRCO4', 'SUNNYSDE']
# ['CHAPELLE', 'LELANDO']
# ['RAM452', 'NSES']
# ['COLHYDRO', 'SCHUYLER']
# ['LACYGNE', 'N345']
# ['CONEM', 'WHEGL']
# ['CROCKERW', 'GROTON']
# ['5WASHBR', 'BEAVER1']
# ['GRANVW', 'GRANDVW', 'EURK_SPA']
# ['CARLISLE', 'TUCO']
# ['HOBBYLO4', 'DATON']
# ['CLEOC1', 'IMO']
# ['STEGALL', 'DC', 'TIE', 'LINE']
# ['WESTPRK', 'HURON']
# ['MSTNG1', 'DVISN']
# ['FTSMTH', 'MUSKOGEE']
# ['CLDONIA', 'EGF_IND', 'FARGO']
# ['NWTEXAR', 'TURK_PP']
# ['UTICAJC', 'XF', 'KV3A']
# ['FTSMTH', 'XF', 'T1_T']
# ['EGF_IND', 'GRNDFKS']
# ['CHERRYC', 'MITCHEL', 'LETCHERW']
# ['XFWATFORDKV2A1230/1WAUE']
# ['CUNCL', 'MSTNG1']
# ['LONGWOO', 'SAREPT']
# ['CHLD_SPP', 'PAUL_SPP']
# ['CHISHOLM', 'SWEETWT6']
# ['GAVINS', 'HARTNGTN']
# ['TH_HILL', 'MCC2']
# ['XFFTTHOMPKU1A1345/1WAUE']
# ['TULSA_NO', 'CLEVLND7']
# ['SUB975', 'SUB1399']
# ['CRAIG', '87TH_ST']
# ['STILWELL', 'W_GARDNR']
# ['STILWELL', 'XF', 'XF11T']
# ['ASB3491', 'LITC']
# ['MARM', 'NSES']
# ['COOPER', 'ST_JOE']
# ['NASHUA', 'HAWTHORN']
# ['MULGRE2', 'SHAYS']
# ['AMOCO_SW', 'SUNDOWN2']
# ['CRAIG', 'LENEXA']
# ['MOORE', 'TOBIAS']
# ['PVLYNSP', 'BYRON2']
# ['ANTELOP', 'ROUNDUP']
# ['PTRBRG_N', 'NELIGH']
# ['CLARMR4', 'OOLG_AEC', 'NE']
# ['5WASHBR', 'NEOSPA']
# ['BLMFLD', 'CREITON']
# ['KELL', 'SUB1399', 'TECH']
# ['RAM452', 'ORO1101']
# ['AVECTYTP', 'MIDWAY5']
# ['CRESTONW', 'ANITA', 'EXIRAWA']
# ['PECAN1', 'FIVE1']
# ['YOAKUM', 'TUCO']
# ['MRYVL_SJ', 'MARYVIL']
# ['LUBBOCKS', 'WOLFFORT']
# ['PTRBRG_N', 'ALBION2']
# ['AES5', 'TARBY1']
# ['LNCANDN', 'CDRLNA138OKGE']
# ['CHARLOT5', 'NRTHEAST']
# ['GRACMONT', 'XF', 'T3_T']
# ['BOBS_CO', 'SUMMITW']
# ['CBLUFFS', 'SUB3456']
# ['SEMINOLE', 'XF', '2_3']
# ['SPRGFLD', 'LAR3821']
# ['HILTOP_E', 'HRSN_E']
# ['LNFRNKLN1', 'MDWSTA138WFEC']
# ['GRIMES', 'BVRCRFBC']
# ['HOPESWTC', 'FULTON_C']
# ['DIANA', 'XF', 'SOUTH_345_138']
# ['LONGWOO', 'SWSHREV']
# ['SWSHREV', 'XF', 'MIDL_T']
# ['CORNVILL', 'SW_STA']
# ['FIVE1', 'HANCK']
# ['AES5', 'HACKETT', 'FTSMTH', 'NHUN']
# ['TRICHEL', 'FORTHUM', 'ARSENAL']
# ['EURK_SPA', 'BEAVER1']
# ['CARPENTR', 'HITCH']
# ['GRPRAIR', 'FTTHOMP']
# ['PLXSUB', 'DEAFSMIT']
# ['HAWKN_LK', 'LYON_CO']
# ['HOSKINS', 'ANTELOP3']
# ['SONR1', 'SNRPMPT4', 'OSAGE_OG']
# ['HARTBG', 'LAYFLD_A']
# ['BELFELD', 'XF', 'KU1A3']
# ['HAWTHORN', 'XF', 'XF22']
# ['GRDA17', 'TONNECE']
# ['KELL', 'SSEN']
# ['SALISBRY', 'TH_HILL']
# ['MCCOOL', 'GRISLD1']
# ['WDRNG1', 'HUNTERS7']
# ['LNOWASSO', 'NE_GASA138CSWS']
# ['CLINTON', 'STILWELL']
# ['LELANDO', 'XF', 'KVA13']
# ['GRDA17', 'GREC3']
# ['PHILL', 'LKWINGB', 'HOOKRD5']
# ['HARBINGR', 'CARPENTR']
# ['HICKMAN', 'STILWELL']
# ['NEBRCTY', '103_ROKE']
# ['HOYT', 'JEFF']
# ['LNLEC', 'LAWH2115WR']
# ['JHNSTNCO', 'XF', 'T3_T']
# ['PHILL', 'SIBLEY']
# ['SUNNYSDE', 'XF', '2_3']
# ['GRACMONT', 'MINCO']
# ['STEELCTY', 'HARBINE']
# ['TEKAMAH', 'TEKAMHO']
# ['STEELCTY', 'KNOB']
# ['MCCLAI', 'WESTMOR4', 'SGATE', 'PENN1']
# ['JHNSTNCO', 'PITTSB9']
# ['LNBLMFLD', 'CREITONA115NPPD']
# ['HOSKINS', 'RAUN']
# ['KELL', 'XF', 'KELL_10']
# ['SIBLEY', 'KETCHEM']
# ['TIP2921', 'MONETT']
# ['LAWH', 'SWLA']
# ['CLARKCO', 'THISTLE7']
# ['G_GENT1', 'XF', '2T']
# ['NUNDRWD', 'ELSWRTH']
# ['SUBJ', 'SUB_A']
# ['OVER', 'MCC2']
# ['VIOLA7', 'WICH']
# ['SUB3740', 'NEBRCTY']
# ['FPLSWTCH', 'MOORLN1']
# ['BUCKNER7', 'HOLCOM1']
# ['SHELLCRK', 'HOSKINS']
# ['HARBINE', 'BEATRICE']
# ['SIOUXFL', 'BERSFRD']
# ['WATERTN', 'WTR15AVE']
# ['OKEENE1', 'WATNGSW']
# ['SWEETW4', 'GRISLD1']
# ['ANTELOP3', 'XF', 'T1']
# ['RVS4385', 'TABLE_RK']
# ['ROSEMONT', 'PAULINE']
# ['CHAR_CK', 'WATFORD']
# ['CHAR_CK', 'XF', 'KV4A']
# ['SHEASLK', 'HELENAMN']
# ['LOGANWA', 'LELANDO']
# ['MARM', 'XF', 'MARM_1']
# ['LNCJ366', 'ASB3491A161EDE']
# ['NEWELL2', 'SULPHSPR']
# ['6TH', 'MIDJ', 'FAIRGNDS']
# ['LAWH', 'XF', 'LAWH_29']
# ['SIOUXCY', 'SIOUXCY2']
# ['AXTELL1', 'PAULINE']
# ['SUB3456', 'NEBRCTY']
# ['GENOA', 'ALBION2']
# ['LAKEFLD', 'DICY']
# ['MEADW_GR', 'KELLY']
# ['N345', 'BLACKBRY']
# ['BORDER', 'WDWRDEHV']
# ['SWEETWT6', 'WHEELER']
# ['NASHUA', 'ST_JOE']
# ['SUB1226', 'TEKAMHO']
# ['DAGLUM', 'BELFELD']
# ['PLTCTY', 'KCI']
# ['FREMONT', 'SCHUYLER']
# ['PIRKEY', 'XF', 'NORTH_345_138']
# ['GRAPVINE', 'KIRBY_SU']
# ['FTTHOMP', 'CHAPELLE']
# ['CHAR_CK', 'ANTELOP']
# ['CARTRCO4', 'HLTNT1']
# ['COLMBS_E', 'SHELLCRK']
# ['WEATH', 'WTH_SE4', 'WFRDT']
# ['DRAPR1', 'XF', 'DRAPER74']
# ['CIMARRON', 'SARA']
# ['BAKER2', 'XF', 'TR13']
# ['OAKLAND', 'TEKAMAH']
# ['LNST_JOE', 'FAIRPORT', 'COOPER345MPS']
# ['SWEETWT6', 'ROARK']
# ['CHAR_CK', 'XF', 'KV2A3']
# ['CIMARRON', 'XF', 'B31']
# ['BODLE', 'BUTRFLD4', 'SBROWN']
# ['GRANITF', 'MORRIS']
# ['DOLET', 'SWSHREV']
# ['BNSF', 'W_GARDNR']
# ['PHILL', 'XF', '345_161']
# ['GRAY_CO', 'HUTCH']
# ['SHELLCRK', 'KELLY']
# ['SONR1', 'DEADSUB', 'WHEGL']
# ['MATHWSN7', 'REDGNTN7']
# ['WATFORD', 'XF', 'KV1A3']
# ['CHAR_CK', 'PATENT_G', '+', 'JUDSON', 'DDR']
# ['WATFORD', 'XF', 'KV2A3']
# ['ELKCKWA', 'NEWELL2']
# ['KEAR_TEC', 'RIVERDAL']
# ['SWIS', 'W_GARDNR']
# ['TURK_PP', 'SUGARHI']
# ['WATERTN', 'WTRPELI']
# ['SHELDON', 'BEAPWRST']
# ['BAI_CO_R', 'CASTRO', 'PLXSUB']
# ['EL_EHV', 'SH_EHV']
# ['EASTX_SW', 'NTXEAST']
# ['SOURIS', 'MAGIC_CY']
# ['MILLR', 'DEADSUB', 'WHEGL']
# ['EASTX_SW', 'WHITNEY']
# ['FIR417', 'CJ366', 'ORO1101', 'ASB3491']
# ['HEIZER', 'MULGRE2']
# ['BANN', 'NWTEXAR']
# ['JUDSON', 'PATENT_G']
# ['HOLCOM1', 'SETAB1']
# ['HITCH', 'POTTER_S']
# ['THISTLE7', 'CLARKCO']
# ['VBI5', 'RUDY5']
# ['TURK_PP', 'OKAY']
# ['ORDWAY', 'BRWNCNTY']
# ['WICH', 'BURN']
# ['ST_JOE', 'XF', 'T33_T']
# ['TANDE', 'TANDELNX', 'JUDSON']
# ['SWSHREV', 'XF', 'EAST_345_138']
# ['LAWH', 'SWIS']
# ['HEIZER', 'NEKOMA1', 'NESCTY']
# ['MARSHAL3', 'SSEN']
# ['POSTROCK', 'SHAYS']
# ['RASMUSN', 'UTICAJC']
# ['FTRANDL', 'SIOUXCY']
# ['WMCP', 'CJOHN', 'MOHA']
# ['LNMCRF', 'EMCPA115WR']
# ['BAKER2', 'BAKERWP']
# ['SUB1280', 'SUB975']
# ['MCROY', 'STILW1']
# ['CHAVES', 'XF', 'CVS_115EXFMR']
# ['EDDY_CO', 'KIOWASPS']
# ['NE_HERFD', 'TBLANCA']
# ['SIOUXCY', 'XF', 'KV1A3']
# ['RAUN', 'SIOUXCY2']
# ['CAR395', 'ASB3491']
# ['WILKES', 'LONGWOO']
# ['DEAFSMIT', 'XF', 'DFS_E115XFMR']
# ['CROSSRDS', 'EDDY_CO']
# ['SGATE', 'PLVAL']
# ['FTRANDL', 'XF', 'TRF']
# ['WOLFFORT', 'SUNDOWN2']
# ['ODESSA1', 'WBURGE1']
# ['HOLT_CO', 'GRISLD1 W/RAS 345 NPPD']
# ['ODESSA1', 'LEX1611']
# ['HOSKINS', 'NORFOLK']
# ['HEREFORD', 'TBLANCA']
# ['FTTHOMP', 'XF', 'KU1B3']
# ['MCCLAI', 'S_LAKES']
# ['COLHYDRO', 'COLMBS_E']
# ['SUNNYSDE', 'HUGOPP4']
# ['WICH', 'BENT']
# ['VIOLA7', 'RENFROW7']
# ['LELANDO', 'GROTON']
# ['BRUNSWC2', 'SALISBRY']
# ['ADD NEW EAST']
# ['KINZE', 'UNVRSTY4', 'MCROY']
# ['EXIRAWA', 'DENISON']
# ['CHERRYRD', 'ANADARKO']
# ['GROTON', 'ABDNSBT']
# ['BROOKNGS', 'AURORAWA']
# ['WHITE', 'WATERTN']
# ['WHITE', 'XF', 'KU1A3']
# ['CKHAL', 'XEROX', 'CIMARRON']
# ['EUREKASP', 'EURK_SPA', 'BEAVER1']
# ['CJ366', 'FIR417', 'ASB3491', 'ORO1101']
# ['DEAFSMIT', 'TBLANCA']
# ['ABDNSBT', 'GROTON 1 115 WAUE']
# ['FTSMTH', 'ARK_NU']
# ['SEMIN', 'MSTNG']
# ['FINNEY1', 'HOLCOM1']
# ['KNOLL1', 'XF', 'A']
# ['HILKEN', 'BISMARK2']
# ['LUBBOCKE', 'CROSBY2']
# ['GROTON_S', 'GROTON']
# ['FTTHOMP', 'HURON']
# ['BUF_FLTS', 'WICH']
# ['JMSTNOTP', 'CENTER2']
# ['JUDSON', 'XF', 'KU6A']
# ['KINZE', 'KINZEG1']
# ['MCLEODN', 'XF', 'TR1']
# ['STILW1', 'SPVALLY2']
# ['INDEP2', 'HOLBOT']
# ['BUSHLAND', 'POTTER_S']
# ['DGRASSE7', 'WDWRDEHV']
# ['DGRASSE7', 'WDWRDEHV']
# ['REDWLO1', 'MINGO1']
# ['WHEELER', 'XF', 'XF1']
# ['NOWST1', 'CIMARRON']
# ['MATHWSN7', 'NOWST1']
# ['OAHE', 'FTTHOMP']
# ['HAYMAKR4', 'CIMARRON', 'DVISN']
# ['LAKEFLD', 'NOBLES']
# ['DOVERS1', 'HENSY']
# ['GRDA17', 'XF', 'NORTH_T']
# ['FTSMTH', 'XF', 'T3_T']
# ['FTRANDL', 'XF', 'TRE3']
# ['NWTEXAR', 'VALLIANT']
# ['CHANNING', 'POTTER_S']
# ['SW_MINOT', 'BERTHOLD']
# ['WELSH', 'WILKES']
# ['DIANA', 'XF', 'NEW_345_138']
# ['CLBTSNWP', 'POPLARWP', 'WILISTN', 'CLB']
# ['LAW_ES', 'TONKAWA']
# ['CHAR_CK', 'BELFELD']
# ['YOAKUM', 'MSTNG']
# ['POTTER_S', 'XF', 'XF345']
# ['GRPRAIR', 'HOLT_CO']
# ['PIRKEY', 'DIANA']
# ['CHAR_CK', 'BELFELD']
# ['IATAN', 'EASTTOWN']
# ['CATSAGR5', 'XF', '3']
# ['CATOOSA', 'CATSAGR5']
# ['LELANDO', 'ANTELOP']
# ['SARA', 'S_LAKES']
# ['JHNSTNCO', 'CANEY1']
# ['LNWEBSTER2', 'LEDYARD345MEC']
# ['COLBY', 'BISONSS']
# ['CATSAGR5']
# ['DATON', 'MSTNG1']
# ['SIOUXCY', 'TWINCHUR']
# ['HOCKERVL', 'XF', 'AA']
# ['WICH', 'RENO']
# ['HOBBS', 'CUNNSUB']
# ['BELFELD', 'DKSNNDWP']
# ['OAHE', 'FTTHOMP']
# ['WDWRDEHV', 'BOBCAT7']
# ['STATLINE', 'PION_SS']
# ['PRIAM', 'MAYNARD', 'KERKHO', 'B']
# ['SCOTTCO', 'HELENAMN']
# ['DAWSONC', 'FTPECK']
# ['BEARCAT', 'MORWODS4']
# ['NSES', 'XF', 'NSES_5']
# ['NASHUA', 'IATAN']
# ['BENT', 'MIDI']
# ['BURN', 'EMPEC']
# ['REDBLUFF', 'RDRUNNER']
# ['EFRMOUNT', 'JARB']
# ['SONR1', 'MILLR']
# ['ROSE', 'OPENSKY7']
# ['NOWST1', 'PDMNT']
# ['WILKES', 'LONSTR_S']
# ['ELGIN_J', 'SW_STA']
# ['WARDWA', 'MANDAN']
# ['MANDAN', 'NAPOLNSW']
# ['ELLENDL2', 'ELLENDL']
# ['CLARKCO', 'SADDLE7']
# ['NEW_RICE', 'XF', 'XF1']
# ['OAHE', 'SULLYBT']
# ['WELSH', 'NWTEXAR']
# ['MATHWSN7', 'TATONGA']
# ['LAWH', 'LEC', '6TH']
# ['DENISON', 'XF', 'KV1A3']
# ['ANADARKO', 'FLETCH3', 'COMANCH2']
# ['OKTAHA', 'MUSKOGEE']
# ['TATONGA', 'WDWRDEHV']
# ['PAYNE_WF', 'CORNVILL', 'ANADAR']
# ['LNFAIRGNDS', 'BISM1115WR']
# ['KNOXLEE', 'XF', '138_69']
# ['ELK-CITY', 'CHISHOLM']
# ['MUSKOGEE', 'SEMINOLE']
# ['LAWH', 'LEC']
# ['NSES', 'N345']
# ['PECAN1', 'RIVRSIDE']
# ['TONKAWA', 'SW_STA']
# ['RIVRSIDE', 'XF', '2_T']
# ['NUTHTCH', 'IFIP 161 ALTW']
# ['SBROWN', 'TUPELO2']
# ['QUINN', 'BLKHAWK']
# ['BSSOUTH', 'TWINBRKS']
# ['RIVRSIDE', 'XF', '1_T']
# ['CDRLN', 'CANADN1', 'WALCK']
# ['ONETA', 'CALPINE']
# ['SUMM', 'WR_SMKHL']
# ['JBORO7', 'CENTRH']
# ['WOLFFORT', 'XF', 'WLF_115XFMR']
# ['YUMA', 'WOLFFORT']
# ['SHELDON', 'FIRTH', 'STERLING']
# ['SWSHREV', 'DIANA']
# ['QUINCY_S', 'MURPHY']
# ['COOPER', 'NEBRCTY']
# ['BA_71', 'ONETA']
# ['BELFELD', 'XF', 'KU2A3']
# ['ARSENAL', 'XF', 'NORTH_138_69']
# ['BIGSTON', 'BROWNSV', 'HANKSON', 'NEWFNG']
# ['ONETA', 'CALPINE']
# ['TOWNER', 'BOTTNOSE']
# ['FREMONT', 'SUB976']
# ['BLANCH_S', 'CORNVILL', 'MAUD_T']
# ['WOLF', 'ROSE']
# ['SIDNEY', 'OGALALA']
# ['MUDDYCRK', 'BROKENB']
# ['HEBRON_N', 'FAIRBURY']
# ['ANTELOP3', 'CREITON']
# ['CRAIG', 'PFLUMM5']
# ['LAWH', 'LEC']
# ['MARM', 'DAKOTA']
# ['GRACMONT', 'WASHIT1']
# ['CHISHOLM', 'XF', 'T1_T']
# ['CORNVILL', 'SW_STA']
# ['MAIZ', 'GORD']
# ['LOC_GROV', 'MAID1', 'CEDARCRS']
# ['MAIN1', 'BATFLD5']
# ['CHAPEL_H', 'WELSH', 'PETTY', 'WILKES']
# ['POSTROCK', 'XF', 'XF1']
# ['WACO', 'COWS']
# ['EMCP', 'CIRC']
# ['MULGRE2', 'SPERVI1']
# ['BOBCAT7', 'WDWRDEHV']
# ['FAIRPORT', 'XF', 'T3']
# ['JUD-LR1', 'NFTDODG3']
# ['LNNORAM', 'LONGWOOA138CSWS']
# ['ZOO_WR', 'GORD']
# ['LYON', 'WHEA']
# ['WICH', 'GORD']
# ['LOSTDRAW', 'PLAINS_S']
# ['EDMONDST', 'LAKE_RD']
# ['HOBART_J', 'MARTHA', 'OMPVET4']
# ['N_LOVING', 'SLOV_NAV']
# ['MINGO1', 'XF', 'T2']
# ['JAY_HAWK', 'FRANKLN5']
# ['WAKE_FLD', 'HOSKINS']
# ['CARLISLE', 'MURPHY']
# ['NMAN', 'ELM_CRK']
# ['STANTNTH', 'HOSKINS']
# ['PANTHER', 'BIRDISLD', 'GRANITF']
# ['PENN1', 'WESTMOR4', 'SGATE', 'MCCLAI']
# ['HOBBS', 'YOAKUM']
# ['ASHERVIL', 'POP_BLF']
# ['MINR', 'KEL']
# ['NMAD_SPA', 'KENNET1']
# ['DELL', 'W_NEWMAD']
# ['IDALIA', 'SKST']
# ['SULPHSPR', 'MAURINE']
# ['GEAR', 'SUMM']
# ['MULGRE2', 'HEIZER']
# ['MONETT', 'LAR3821']
# ['MIDJ', 'LAWH']
# ['COMS_AMR', 'SKST']
# ['DIANA', 'XF', 'C_345_138_TS']
# ['ROSEAU', 'RIEL']
# ['HOYT', 'XF', 'HOYT44T']
# ['ELLENDL2', 'ELLENDL']
# ['SPLT_RT', 'WHITE']
# ['TECH', 'SWLA', 'LAWH']
# ['MINGO1', 'SETAB1']
# ['BAILEY', 'CURRY2']
# ['HOLWD', 'PLVAL']
# ['DBLTEMPLKFLNLAKEF34_1345']
# ['LONEG', 'WLFCK', 'SUNNYSDE']
# ['WESTERN', 'SSHREVE']
# ['SSHREVE', 'SWSHREV']
# ['CIRC', 'NEW_RICE']
# ['ELK-CITY', 'REDHILLS']
# ['CUNNSUB', 'HOBBS']
# ['SUB1206', 'CBLUFFS']
# ['BROOK_LN', 'XF', 'T1']
# ['MORR', 'XF', 'MORR_105']
# ['SIOUXFL', 'PAHOJA']
# ['LAW_ES', 'COMANCHE', 'DUNCAN']
# ['LOSTDRAW', 'COCHRAN']
# ['BADGER7', 'BOBCAT7']
# ['MULGRE2', 'XF', 'AC']
# ['BOBCAT7', 'BADGER7']
# ['87TH_ST', 'STRA']
# ['W_NEWMAD', 'ESEX', 'LUTS']
# ['CHAMBERS', 'CLRKSVLE']
# ['ROSEMONT', 'GUIDER']
# ['KETCH', 'OMMITCH4', 'NOWST1', 'OMWHITE']
# ['TREASURE', 'LAW_ES']
# ['JONES_KA', 'ARCAD7']
# ['STILWELL', 'LACYGNE']
# ['LAWH', 'LEC']
# ['GRASSLAN', 'JONESSUB']
# ['LAW_ES', 'XF', '5']
# ['CDRLN', 'DRAPR1', 'WLKNS']
# ['CROSSTWN', 'CLASN']
# ['SW_STA', 'NORGE_RD']
# ['MILCRK', 'HRTHL', 'PINELAND']
# ['MOORE', 'COOPER']
# ['NEOSPA', 'TIP2921']
# ['VTHANLON', 'SIOUXFL']
# ['WEBSTER2', 'XF', 'WEB_AB_WNDNG3']
# ['MOORE_CO', 'XF', 'MC_115XFMR']
# ['AGNCY1', 'PECAN1']
# ['DRIVER', 'SANSSU']
# ['SUNNYSDE', 'TERRY_RD']
# ['ANADARKO', 'SW_STA']
# ['PATNT_G1', 'LCSWITCH']
# ['DAGLUM', 'RHAME']
# ['KELL', 'GOFF']
# ['GRAINVL5', 'BLSPE']
# ['NORTON', 'MALTABN5']
# ['SUB_C', 'SUB_N']
# ['JOLLYVL4', 'PRICESF4', 'HONEYCRK']
# ['CHTWOOD4', 'JONES2', 'ARCAD7']
# ['SEMINOLE', 'MAUD_TAP']
# ['CRESTONW', 'MARYVIL']
# ['RIVRSIDE', 'ORU_OLD', 'SO_HILLS', '81_']
# ['SHOOTSTR', 'NFTDODG3']
# ['ST_JOE', 'EASTTOWN']
# ['SUB3456', 'SUB3459']
# ['OSGOOD', 'BURT']
# ['AINSWRT', 'VALENTN']
# ['BEARCAT', 'MORWODS4']
# ['MARTIN', 'HUTCH']
# ['RIVROAD', 'BARBER3']
# ['SANTAFE4', 'CORNVILL']
# ['LYON_CO', 'CEDAR_MT']
# ['CHAR_CK', 'BELFELD']
# ['STILWELL', 'REDEL5']
# ['ROCKYC', 'CROCKETT']
# ['OGALALA', 'LN', 'OGALALA_1135']
# ['BLAISDEL', 'LOGANWA']
# ['ANTELOP', 'LELANDO']
# ['GRANITF', 'XF', 'KV3A3']
# ['HOBBS', 'KIOWASPS']
# ['JONESSUB', 'LUBBOCKE']
# ['ARCAD7', 'XF', 'C2']
# ['BEE1', 'EXGLN4', 'RIVRSIDE']
# ['NELSONTP', 'MINOT']
# ['FLANDRU', 'SIOUXFL']
# ['STAPLETN', 'MAXWELL']
# ['95WA', '87TH_ST']
# ['EASTRUTH', 'SW_MINOT']
# ['RUGBY230', 'BALTAGRE']
# ['FARGO', 'XF', 'KV2A3']
# ['TULSA_NO', 'XF', '1']
# ['LONE_OAK', 'TUSKAHOM']
# ['HOLWD', 'DRAPR1', 'FRNKLN1']
# ['LNMAIN1', 'BATFLD5A161SPRM']
# ['ARSENAL', 'STALL_PP']
# ['LUBBOCKE', 'XF', 'LBE_115XFMR']
# ['81_YALE', 'WARRENM', '96YALE', 'RIVRSI']
# ['TUCO', 'YOAKUM']
# ['ELM_CRK', 'CONCOR3']
# ['LNCENTER2', 'JMSTNOTP345KVOTP']
# ['VALLIANT', 'HUGOPP4']
# ['JMSTNOTP', 'BUFFALO2']
# ['LNFORBTAP', 'CHIS_CO1500NSP']
# ['BLAIR', 'OTPBLAIR', 'GRANITF']
# ['VALENTN', 'MISSION']
# ['DONALDS', 'DRAYTON']
# ['SIOUXCY2', 'SPLT_RT']
# ['OTPBLAIR', 'BIGSTON']
# ['MCCLAI']
# ['LANG', 'WEMP']
# ['BRKNGCO', 'OTP_ASTO']
# ['RAMSEY', 'BALTAGRE']
# ['CHAVES', 'EDDY_CO']
# ['OKLAUNIO', 'LAW_ES']
# ['RNDBARN4', 'ARCAD7 A 138 OKGE']
# ['DATON', 'SCI1']
# ['ARCAD7', 'XF', 'C3']
# ['CHIS_CO', 'FORBTAP']
# ['FTTHOMP', 'WESSPRNG']
# ['MATHWSN7', 'TATONGA']
# ['BENNGTN', 'BOSWELL', 'BLUEBIRD']
# ['RUSET', 'SBROWN']
# ['GRASSLAN', 'XF', 'T2']
# ['MOORLN1', 'ASPEN']
# ['SIOUXFL', 'XF', 'KV5A3']
# ['SHELL_CO', '', 'ODC', 'YOAKUM 115 SPS']
# ['SEMINOLE', 'LKKONAWA', 'PRKLN1']
# ['NBENTON', 'LIEBERM']
# ['CROCKERW', 'WATERTN']
# ['SMOK', 'SUMM']
# ['MONT3', 'STATLINE']
# ['CNTRVILL', 'PAOLA']
# ['WATERTN', 'APPLDORN']
# ['FLINTCRK', 'TONNECE']
# ['DEUELCO', 'BSSOUTH']
# ['CLEARVIE', '87TH_ST']
# ['TUCO', 'JONESSUB']
# ['MCC2', 'OVER']
# ['NSES', 'XF', 'NSES_4']
# ['RHAME', 'BOWMANWP']
# ['FTTHOMP', 'OAHE']
# ['NAVY', 'GA_WEST', 'NRTHEAST']
# ['HUGHCNTY', 'OAHE']
# ['CLARKCO', 'SPERVI1']
# ['LNBLAIR', 'BIGSTONNEW230OTP']
# ['ELK-CITY', 'HOBART_J']
# ['BARBER', 'ROSEDALE']
# ['QUIND1', 'NEARMAN']
# ['SONR1', 'XF', 'AA']
# ['CTNWD1', 'CRESCENT']
# ['MOORLN1', 'OKEENE1']
# ['KAWW1', 'METROPOL']
# ['AINSWRT', 'AINSWIND']
# ['VIOLA7', 'SUMNER']
# ['WATERTN', 'XF', 'KU1A3']
# ['GRNDFKS', 'PICKRTWA']
# ['LNNICHSUB', 'CONWAY1115SPS']
# ['WAYSID_W', 'NUNDRWD']
# ['REMSNSRT', 'RAUN']
# ['GARRISN', 'JAMESTN']
# ['GRNDFKS', 'PRAIRIE2']
# ['MIDLAND2', 'IRVSIMM']
# ['OKLAUNIO', 'TUCO']
# ['DEWEY1', 'WDWRDEHV']
# ['DB LPOSTROCK', 'SHAYS B 230 WR']
# ['THISTLE7', 'BUF_FLTS']
# ['HAWTHORN', 'BLUE_VLY']
# ['NORMHLL', 'MCCLAI', 'PLVAL']
# ['DRAPR1', 'CIMARRON', 'NORMHLL']
# ['SIOUXFL', 'XF', 'KV3A3']
# ['LNMAURINE', 'BISON', 'HETINGRW230WAUE']
# ['WFRDG', 'WFRDT']
# ['DOSS2', 'SEMIN']
# ['LYON', 'NEW_RICE']
# ['PAULINE', 'TOBIAS']
# ['SWDISP', 'BATFLD5', 'SWPS5']
# ['ELLENDL2', 'TWINBRKS']
# ['ONETA', 'CLRKSVLE']
# ['SUB1260', 'SUB1361']
# ['POPLARWP', 'WOLFPT']
# ['COFFEYT4', 'DEAR']
# ['BATFLD5', 'SPRGFLD']
# ['LEVEE', 'NRTHEAST']
# ['ETTA', 'HS_EHV']
# ['TULSA_PS', '36OLYMP']
# ['GMPLT', 'QUIND1']
# ['BA_NORTH', 'ONETA', 'E_11_ST']
# ['HOLT_CO', 'GRISLD1']
# ['DELAWARE', 'XF', '1']
# ['CARDINAL', 'NEF_S']
# ['ENDERLNW', 'LN', 'BEARCRKM_LDTIE']
# ['IATAN', 'STRA']
# ['SQBUTTEW', 'STANTON2']
# ['JAMESTN', 'VALLEYC']
# ['NODAWAY', 'MARYVIL']
# ['HETINGRW', 'BOWMANWP']
# ['MAURINE', 'XF', 'KV1A3']
# ['CENTER2', 'RGHRIDER']
# ['OAHE', 'IRVSIMM']
# ['JEFF', 'MORR']
# ['DBLFRANKLIN', 'EMERYKILLDEER', 'BLACKH']
# ['N_LOUP', 'LOUPCTY']
# ['TRIBOJI', 'DICY']
# ['FREMONT', 'WINSLOW', 'OAKLAND']
# ['PIRKEY', 'LEBROCK']
# ['TL_SIXMI', 'TL_HEMPH', 'FAIRMOU']
# ['SONR1', 'RANCHRD7']
# ['BURT', 'OSGOOD']
# ['QUINN', 'KILLDEER']
# ['BUSHLAND', 'XF', '728B']
# ['POTTER_S', 'XF', 'T1_T']
# ['KNOXLEE', 'XF', '138_69']
# ['CASTRO', 'NEWHART']
# ['MARTHA', 'HOBART_J', 'OMPVET4']
# ['CND_RIVR', 'PITTSB9']
# ['RDRUNNER', 'PHANTM']
# ['QUINN', 'KILLDEER']
# ['WRIGHT2', 'WEBSTER2']
# ['THISTLE7', 'CLARKCO']
# ['WDWRDEHV', 'XF', 'XF3_T']
# ['CHOUT_AE', 'MAID1']
# ['EGY_CNTR', 'HASTING_']
# ['HASTING_', 'EGY_CNTR']
# ['SALISBRY', 'NORTON']
# ['MCK_KD', 'KILDEER']
# ['SW_MINOT', 'LOGANWA']
# ['PATNT_G1', 'PATENT_G']
# ['BRDLAND', 'ANTELOP']
# ['TATONGA', 'WDWRDEHV']
# ['TUCO', 'XF', 'TUC_230XFMR_S']
# ['FORMAN', 'XF', 'TR13']
# ['SW_STA', 'HOBART_J']
# ['RAUN', 'XF', 'RAU_AC_WNDNG3']
# ['OAKGRV', 'ODESSA1', 'GRAINVL5']
# ['RENFROW7', 'VIOLA7']
# ['ENDERLNW', 'ELLIOTTW']
# ['HETINGRW', 'BISON', 'MAURINE']
# ['FOSTR', 'DISCVRY4']
# ['LELANDO2', 'LELANDO']
# ['ROANRDGE', 'TIFFANY']
# ['NUNDRWD', 'PHILTAP']
# ['PINTAIL', 'SONR1']
# ['NOWST1', 'ONEOK']
# ['COOPER', 'ATCHISNM']
# ['DOLET', 'XF', 'DOLET_AUTO']
# ['RAINSRD', 'LONGWOO']
# ['HURON', 'BRDLAND']
# ['ELK-CITY', 'CLINT_J']
# ['ELK-CITY', 'HOBART_J']
# ['MORWODS4', 'REDHILLS']
# ['WALLE', 'PRARIE2', '230']
# ['SUB983', 'SUB6846']
# ['FLAT_RDG', 'BARBER3']
# ['OTP_ASTO', 'DEUELCO']
# ['ADAMSMEC', 'BROOKMEC']
# ['SIDNEYM', 'SIDNEY']
# ['RKYPT1', 'SUNNYSDE']
# ['MARIET1', 'LOCO']
# ['E_NEMAHA', 'KELL']
# ['ARCAD7', 'MEMRL', 'HSL1']
# ['HANKSON', 'NEWFNGTN']
# ['LNM_TOWN', 'TIMBRCK']
# ['COLMBSCO', 'COLMBS_E']
# ['COLHYDRO', 'KELLY']
# ['SEMIN', 'GAINES_C']
# ['HUNTLEY2', 'WILMART']
# ['STEGALL', 'XF', 'KV3A3']
# ['BRYNT', 'MEMRL', 'ACORN', 'HSL1', 'CHTWOO']
# ['CAROLL', 'DOLET']
# ['WHEA', 'WMCP']
# ['WAYSIDE', 'WAYSID_W']
# ['CIM-PL1', 'HAYNE']
# ['HARTSISL', 'SSHREVE']
# ['LELANDO', 'ANTELOP', 'LELANDO2']
# ['CROCKETT', 'XF', 'B']
# ['PAOLA', 'CENTNIAL']
# ['KNOLL1', 'POSTROCK']
# ['ANTELOP', 'LELANDO2', 'LELANDO']
# ['OVRLD_PK', 'PFLUMM5']
# ['WAVERLY7', 'WOLF']
# ['WTH_SE4', 'WFRDT', 'WEATH']
# ['HOLCOM1', 'XF', 'AC']
# ['WALKMY1', 'HARBINGR']
# ['BLANCO', 'FLOYD_C1']
# ['CRESTONW', 'ADAMSMEC']
# ['COWCK1', 'MORSN', 'STILW1', 'SONR1']
# ['JUNCTN5', 'BROOK_LN']
# ['MADDOXSU', 'HOBBS']
# ['MINCO', 'NORMHLL']
# ['BUCKNER7', 'SPERVI1']
# ['JHNSTNCO', 'SUNNYSDE']
# ['CARPENTR', 'FINNEY1']
# ['EURK_SPA', 'GRANDVW', 'GRANVW']
# ['MATO', 'GRACMONT']
# ['RVS4385', 'HOL478']
# ['CIMARRON', 'NORMHLL']
# ['LEBROCK', 'PIRKEY']
# ['JEFF', 'EMAN']
# ['PLVAL', 'CHRCK', 'NORMHLL']
# ['MCRF', 'EMCP']
# ['CENTER2', 'SQBUTTEW']
# ['BISMARK2', 'WARDWA']
# ['THISTLE7', 'DGRASSE7']
# ['SIDNEYM', 'LARAMIE']
# ['BARBER', 'TERRACE']
# ['BURN2', 'MTGY']
# ['WATERPP', 'WTRWEST']
# ['NAVY', 'TERRACE', 'GA_WEST']
# ['ARCAD7', 'SEMINOLE']
# ['G_GENT1', 'OGALALA']
# ['PLVAL', 'NORMHLL']
# ['JEFF', 'XF', 'JEFF13T']
# ['6TH', 'LAWH']
# ['CIM-PL1', 'WALKMY1']
# ['WR_SMKHL', 'KNOLL1']
# ['RLNGHILS', 'POTTER_S']
# ['HUGOTON', 'PIONEE2']
# ['COMS_AMR', 'MINR 161 AMRN']
# ['SUB1258', 'SUB1366']
# ['HUBEN', 'FRKS']
# ['WAYSIDE', 'CHADRON']
# ['BURN2', 'MCC2']
# ['MEMRL', 'SKYLN']
# ['N-LIBE1', 'LIBERAL_']
# ['TERRY_RD', 'LAW_ES']
# ['SHWNMSN5', 'LENEXA']
# ['CRAIG', 'XF', 'XF22']
# ['BATSV5', 'LS_POW']
# ['SIDNEYM', 'STEGALL']
# ['ORENTDRT', 'NBOROCSN']
# ['COOK2', 'ST_JOE']
# ['ROCKHIL', 'CHEROKE2', 'KNOXLEE']
# ['RVS4385', 'TABLE_RK']
# ['BATTLEF5', 'MASRD1', 'COLNY', 'PLANTER']
# ['BRLNG', 'FTSMTH']
# ['RKYPT1', 'SUNNYSDE']
# ['PENT', 'JARB']
# ['ABDNSBT', 'REDFLD']
# ['NASHUA', 'XF', 'T1_T']
# ['IMO', 'GLENWOOD', 'NEENID4']
# ['MITCHNW', 'MITCHEL']
#     Source Sink               Voltage    Company
# 0        M    I               [345.0]       AECI
# 1        M    I  [230.0, 115.0, 41.6]        OTP
# 2        M    I               [230.0]        SPS
# 3        M    I               [345.0]  AECI AMRN
# 4        M    I               [115.0]   CSWS SPS
# ..     ...  ...                   ...        ...
# 638      M    I               [161.0]       OKGE
# 639      M    I               [138.0]       OKGE
# 640      M    I               [115.0]         WR
# 641      M    I               [115.0]       WAUE
# 642      M    I               [115.0]       WAUE
#
# [643 rows x 4 columns]
